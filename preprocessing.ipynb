# %%
# scrapping from 
import pandas as pd 
df1 = pd.read_csv("scrappig.csv")
df2 = pd.read_csv("Hindi.csv")
df3 =  pd.read_csv("telugu.csv")

# %%
df3
# Out:
#                                   Phrase                              Meaning  \
# 0                            Guddha naku                              Lick as
# 1                 Guddha pagala dengutha  I will fuck the ass untill breakage
# 2                                aathulu                           pubic hair
# 3                          aathulu peeku                       pluck my pubes
# 4                       aathulu peekutha                     pluck your pubes
# 5                             Aati Mokka                           Pubic hair
# 6                akka bokka lO naa sulla            my dick in sister's pussy
# 7                akka nee pooku dengutha                sister, i'll fuck you
# 8                  amma pooku ki baanisa              slave to mother's pussy
# 9              amma pooku lo arati pandu               banana in mommys pussy
# 10             ATTHA POOKU DENGINA ALLDU  SON IN LAW WHO FUCKED MOTHER IN LAW
# ...

# %%
df2
# Out:
#                       aand
# 0                    aandu
# 1                 balatkar
# 2                beti chod
# 3                   bhadva
# 4                   bhadve
# ..                     ...
# 90     teri maa ka bhosada
# 91  teri maa ka boba chusu
# 92        teri maa ki chut
# 93                  tharak
# 94                  tharki
#
# [95 rows x 1 columns]

# %%
df1.shape
# Out:
# (122, 3)

# %%
df2.shape
# Out:
# (95, 1)

# %%
df3.shape
# Out:
# (114, 3)

# %%
df1.info
# Out:
# <bound method DataFrame.info of                                    Phrase                         Meaning  \
# 0                 maari tatoori ne chalay                    Ride my dick
# 1                       Akbaruddin Owaisi                    Biggest cunt
# 2                      Alloo Bhosri Chaat            Lick my potato pussy
# 3                                    Anuj                   Biggest choot
# 4                               Babhuchak                           idiot
# ..                                    ...                             ...
# 117                     teree maah gaderi            Your mum is a donkey
# 118  thari ma ne bozro maro loro nakhides  ill stick my penis up your mum
# 119                     Thari Ma Ni Ghaan                   Your Mums Ass
# 120                                 Tusat                   Sheep shagger
# 121               Tutelli nirodh no aulad          Son of a broken condom
#
#     Is This Accurate?
# 0           (1%) (1%)
# ...

# %%
df2.info
# Out:
# <bound method DataFrame.info of                       aand
# 0                    aandu
# 1                 balatkar
# 2                beti chod
# 3                   bhadva
# 4                   bhadve
# ..                     ...
# 90     teri maa ka bhosada
# 91  teri maa ka boba chusu
# 92        teri maa ki chut
# 93                  tharak
# 94                  tharki
#
# [95 rows x 1 columns]>

# %%
df3.info
# Out:
# <bound method DataFrame.info of                        Phrase                      Meaning Is This Accurate?
# 0    "KUTH-TII" (or) "KUTTII"                        Bitch         (0%) (0%)
# 1          AAGA (or) GUUUUUUU                         Shit         (1%) (0%)
# 2              amar nunu chat                Suck my dick!         (1%) (1%)
# 3        Ami Tumarae Khortham                 I Wanna Do U         (0%) (0%)
# 4                       Ashiq                   Penis Hair        (7%) (26%)
# ..                        ...                          ...               ...
# 109            tu ekta bandar  Your a dumbass/monkey/idiot        (10%) (2%)
# 110           Tur booga sooto          Your dick is small.         (1%) (1%)
# 111        tur mar booni khaa          suck your mums tits         (1%) (1%)
# 112            tuy ath marros                your a wanker         (1%) (0%)
# 113                   Vogchod                         fool        (10%) (3%)
#
# ...

# %%
df1.drop(['Meaning','Is This Accurate?'],
  axis='columns', inplace=True)

# %%
df3.drop(['Meaning','Is This Accurate?'],
  axis='columns', inplace=True)

# %%
df1.head()
# Out:
#                     Phrase
# 0  maari tatoori ne chalay
# 1        Akbaruddin Owaisi
# 2       Alloo Bhosri Chaat
# 3                     Anuj
# 4                Babhuchak

# %%
df2.head()
# Out:
#         aand
# 0      aandu
# 1   balatkar
# 2  beti chod
# 3     bhadva
# 4     bhadve

# %%
df3.head()
# Out:
#                      Phrase
# 0  "KUTH-TII" (or) "KUTTII"
# 1        AAGA (or) GUUUUUUU
# 2            amar nunu chat
# 3      Ami Tumarae Khortham
# 4                     Ashiq

# %%
frames = [df1, df2 , df3]
df4 = pd.concat(frames)

# %%
df4 = pd.DataFrame({'Column': df4.values.reshape(-1)})

# %%
df4
# Out:
#                       Column
# 0    maari tatoori ne chalay
# 1                        NaN
# 2          Akbaruddin Owaisi
# 3                        NaN
# 4         Alloo Bhosri Chaat
# ..                       ...
# 657                      NaN
# 658           tuy ath marros
# 659                      NaN
# 660                  Vogchod
# 661                      NaN
#
# [662 rows x 1 columns]

# %%
df4.shape
# Out:
# (662, 1)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df4
# Out:
#                                                 Column
# 0                              maari tatoori ne chalay
# 1                                                  NaN
# 2                                    Akbaruddin Owaisi
# 3                                                  NaN
# 4                                   Alloo Bhosri Chaat
# 5                                                  NaN
# 6                                                 Anuj
# 7                                                  NaN
# 8                                            Babhuchak
# 9                                                  NaN
# 10                                       bai no bhosdo
# 11                                                 NaN
# 12                                           bein chod
# 13                                                 NaN
# 14                                             Benchod
# 15                                                 NaN
# ...

# %%
finaldf = df4.drop_duplicates()

# %%
finaldf.shape
# Out:
# (330, 1)

# %%
finaldf
# Out:
#                                                 Column
# 0                              maari tatoori ne chalay
# 1                                                  NaN
# 2                                    Akbaruddin Owaisi
# 4                                   Alloo Bhosri Chaat
# 6                                                 Anuj
# 8                                            Babhuchak
# 10                                       bai no bhosdo
# 12                                           bein chod
# 14                                             Benchod
# 16                                              Bhadvo
# 18                                            bhenchod
# 20                                               Bhoot
# 22                                               Bhopa
# 24                                         Bhos marina
# 26                                        Bhosad Pappu
# 28                                              bhosdo
# ...

# %%
# Out:
#                                           Column
# 0                        maari tatoori ne chalay
# 1                                            NaN
# 2                              Akbaruddin Owaisi
# 4                             Alloo Bhosri Chaat
# 6                                           Anuj
# 8                                      Babhuchak
# 10                                 bai no bhosdo
# 12                                     bein chod
# 14                                       Benchod
# 16                                        Bhadvo
# 18                                      bhenchod
# 20                                         Bhoot
# 22                                         Bhopa
# 24                                   Bhos marina
# 26                                  Bhosad Pappu
# 28                                        bhosdo
# 30                                      bhosrini
# 32                                         bobla
# ...
